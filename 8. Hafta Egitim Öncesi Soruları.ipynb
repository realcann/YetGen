# %% [markdown]
# # Problem 1
# Kullanıcıdan aldığı ürün bilgisini (ad, fiyat) urunler.txt dosyasına kayıt eden fonksiyonu yazınız.

# %%
import os
file_path = "ürünler.txt"
mode = os.stat(file_path).st_mode 
print(oct(mode)[-3:])
print(os.path.isfile(file_path)) 
with open("ürünler.txt", "r", encoding="utf-8") as file:
    print(file.read())
# yukarıyı herşey yolunda mı diye yazdım
def ürün_ekleme():
    ü_isim = input("Ürün adı giriniz")
    ü_fiyat = float(input("Fiyat giriniz"))
    file = open("ürünler.txt","a",encoding="utf-8")
    file.write(f"{ü_isim},{ü_fiyat}")
    file.close()
ürün_ekleme()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import os
#       2 file_path = "ürünler.txt"
# ----> 3 mode = os.stat(file_path).st_mode
#       4 print(oct(mode)[-3:])
#       5 print(os.path.isfile(file_path))
#
# FileNotFoundError: [WinError 2] Sistem belirtilen dosyayı bulamıyor: 'ürünler.txt'

# %% [markdown]
# # Problem 2
# 1.problemde oluşturulan text dosyası içerisinde kullanıcıdan alacağımız eski kelime isimli değişkene atadığımız
# ve değiştirilmesini istediğimiz kelimemizi yerini alıcak olan yeni kelime isimli değişkene atayın. Belirlenen kelimeleri text dosyasında değiştiren fonksiyonu yazınız.

# %%
def degisim():
    dosya_adi = input("Dosya adi giriniz :")
    eski_isim= input("Değiştirmek istediğiniz ismi giriniz :")
    yeni_isim = input("Yeni ismi giriniz :")
    with open(dosya_adi, "r", encoding="utf-8") as file:
        bilgi = file.read()
    yeni_bilgi = bilgi.replace(eski_isim,yeni_isim)
    with open(dosya_adi, "w", encoding="utf-8") as dosya:
        dosya.write(yeni_bilgi)
degisim()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 10
#       8     with open(dosya_adi, "w", encoding="utf-8") as dosya:
#       9         dosya.write(yeni_bilgi)
# ---> 10 degisim()
#
# Cell In[1], line 5, in degisim()
#       3 eski_isim= input("değişmek istediğiniz ismi giriniz :")
#       4 yeni_isim = input("yeni ismi giriniz :")
# ----> 5 with open(dosya_adi, "r", encoding="utf-8") as file:
#       6     bilgi = file.read()
#       7 yeni_bilgi = bilgi.replace(eski_isim,yeni_isim)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'a'

# %% [markdown]
# # Problem 3
# Vehicle sınıfının tüm değişkenlerini ve yöntemlerini devralacak bir alt sınıf olarak Bus sınıfı oluşturunuz.
#
#
#
# ```
# Output
# > Name: School Volvo Speed: 180 Mileage: 12
# ```

# %%
class Vehicle:
    def __init__(self, model, hız,):
        self.model = model
        self.hız = hız
        self.yıl = yıl
class Bus(Vehicle):
    def __init__(self, model, hız, km):
        super().__init__(model, hız)
        self.km = km
araç = Bus(Vehicle)("chevrolet","rezzo","220","10")
print(araç)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       8         super().__init__(model, hız)
#       9         self.km = km
# ---> 10 araç = Bus(Vehicle)("chevrolet","rezzo","220","10")
#      11 print(araç)
#
# TypeError: Bus.__init__() missing 2 required positional arguments: 'hız' and 'km'
