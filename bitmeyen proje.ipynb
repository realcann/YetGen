# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import random

class RecipeRecommendation:
    def __init__(self, csv_file):
        self.recipes_df = pd.read_csv(csv_file)
        self.ingredients_vectorizer = CountVectorizer()
        self.ingredients_matrix = self.ingredients_vectorizer.fit_transform(self.recipes_df['ingredients'])
        self.tags_vectorizer = CountVectorizer()
        self.tags_matrix = self.tags_vectorizer.fit_transform(self.recipes_df['tags'])

    def recommend_by_ingredients(self, user_input):
        user_ingredients_list = user_input.split(',')
        user_ingredients_doc = ''
        for ingredient in user_ingredients_list:
            user_ingredients_doc += ingredient.strip() + ' '
        user_ingredients_vec = self.ingredients_vectorizer.transform([user_ingredients_doc])
        similarities = cosine_similarity(user_ingredients_vec, self.ingredients_matrix).flatten()
        recommendations = similarities.argsort()[::-1][:5]
        for i, recommendation in enumerate(recommendations):
            print(f"{i+1}. {self.recipes_df.loc[recommendation, 'name']} ({similarities[recommendation]:.2f} similarity)")
            print(self.recipes_df.loc[recommendation, 'ingredients'])
            print("*"*20)

    def recommend_by_tags(self, user_input):
        user_tags_list = user_input.split(',')
        user_tags_doc = ''
        for tag in user_tags_list:
            user_tags_doc += tag.strip() + ' '
        user_tags_vec = self.tags_vectorizer.transform([user_tags_doc])
        similarities = cosine_similarity(user_tags_vec, self.tags_matrix).flatten()
        recommendations = similarities.argsort()[::-1][:5]
        for i, recommendation in enumerate(recommendations):
            print(f"{i+1}. {self.recipes_df.loc[recommendation, 'name']} ({similarities[recommendation]:.2f} similarity)")
            print(self.recipes_df.loc[recommendation, 'ingredients'])
            print("*"*20)

    def recommend_by_name(self, recipe_name):
        recommendations = []
        for index, row in self.recipes_df.iterrows():
            if isinstance(row['name'], str) and recipe_name in row['name'].lower():
                recommendations.append(row)
        if len(recommendations) > 0:
            print(f"{len(recommendations)} found suggestions:\n")
            for i, recommendation in enumerate(recommendations):
                print(f"{i+1}. {recommendation['name']}")
                print(recommendation['ingredients'])
                print("*"*20)
        else:
            print("No recipes were found matching your search criteria..")


class RandomRecipeRecommendation:
    def __init__(self, csv_file):
        self.recipes_df = pd.read_csv(csv_file)
    
    def recommend_random(self, n=5,):
        recommendations = random.sample(range(len(self.recipes_df)), n)
        recommended_recipes = []
        for i, recommendation in enumerate(recommendations):
            recommended_recipes.append(f"{i+1}. {self.recipes_df.loc[recommendation, 'name']}\n{self.recipes_df.loc[recommendation, 'ingredients']}\n{'*'*20}")
        return recommended_recipes

while True:
    
    print("""
        ******************************
        *        Welcome        *
        * Search by materials........1 *
        * Random Suggestion............2 *
        * Search by TAG............3 *
        * Search by the food name......4 *
        * Exit....................q *
        ***********************
        """)
    choice = input("Please select an option: ")

    if choice == "q":
        print("Bon Appetit!")
        print("Have a nice day!")
        break
        
    elif choice == "1":
        a = input("Please enter the materials with commas between them.: ")
        recommendation_system = RecipeRecommendation('Book2.csv')
        recommendation_system.recommend_by_ingredients(a)
       
        

    elif choice == "2":
        random_recommendation_system = RandomRecipeRecommendation('Book2.csv')
        recommended_recipe = random_recommendation_system.recommend_random()
        for satir in recommended_recipe:
            print(satir)
         

    
    elif choice == "3":
        b = input("Please enter the TAG's with commas between them.: ")
        recommendation_system = RecipeRecommendation('Book2.csv')
        recommendation_system.recommend_by_tags(b)
        
    
    elif choice == "4":
     c = input("Please enter a food name ")
     recommendation_system = RecipeRecommendation('Book2.csv')
     recommendation_system.recommend_by_name(c)
# Out:
#         ******************************
#         *        Welcome        *
#         * Search by materials........1 *
#         * Random Suggestion............2 *
#         * Search by TAG............3 *
#         * Search by the food name......4 *
#         * Exit....................q *
#         ***********************
#
# 2453 found suggestions:
#
# 1. a bit different  breakfast pizza
# ['prepared pizza crust', 'sausage patty', 'eggs', 'milk', 'salt and pepper', 'cheese']
# ********************
# 2. pizza  stuffed potato
# ['baking potato', 'mozzarella cheese', 'tomato sauce', 'part-skim ricotta cheese', 'oregano leaves', 'garlic powder', 'parmesan cheese']
# ********************
# 3. pizza pan  potato skins
# ['potatoes', 'bacon', 'cheddar cheese', 'green onions', 'oil', 'salt', 'sour cream']
# ********************
# 4. pizza  steak
# ['plain flour', 'salt', 'pepper', 'boneless eye of round beef steak', 'onion', 'canola oil', 'pizza sauce', 'parmesan cheese', 'mozzarella cheese']
# ********************
# 5. 5 minute bread  pizza
# ['extra virgin olive oil', 'black olives', 'white onion', 'red bell pepper', 'pepperoni', 'portabella mushrooms', 'mozzarella cheese', 'pizza sauce']
# ********************
# 6. jiffy  deluxe pizza sticks
# ['pizza crust mix', 'garlic powder', 'tap water', 'pepperoni slices', 'mozzarella cheese', 'parmesan cheese', 'margarine']
# ********************
# 7. pizza  beans
# ['dried beans', 'bay leaves', 'onion', 'green peppers', 'garlic cloves', 'italian herb seasoning', 'smoked paprika', 'chili flakes', 'chopped tomatoes', 'tomato paste', 'salt', 'sugar']
# ********************
# 8. big mac  pizza
# ['thousand island dressing', 'prepared pizza crust', 'lean ground beef', 'colby-monterey jack cheese', 'bacon', 'dill pickle', 'prepared mustard', 'lettuce', 'tomatoes']
# ********************
# 9. 1 dish pizza bake
# ['flour', 'sugar', 'salt', 'fast rising yeast', 'water', 'olive oil', 'italian sausage', 'green bell pepper', 'onion', 'garlic cloves', 'tomato sauce', 'italian seasoning', 'oregano', 'mozzarella cheese', 'pepperoni', 'parmesan cheese']
# ********************
# 10. 1 dish italian 5 cheese pizza bake
# ['cooking spray', 'all-purpose flour', 'fast rising yeast', 'sugar', 'salt', 'water', 'olive oil', 'pizza sauce', 'fresh mozzarella cheese', 'five cheese blend', 'italian herb seasoning']
# ********************
# 11. 10 minute pizza snacks
# ['crescent roll dough', 'cream cheese', 'italian seasoning', 'pepperoni', 'cheddar cheese']
# ********************
# 12. 100  whole grain pizza dough
# ['honey', 'active dry yeast', 'warm water', 'salt', 'whole wheat flour', 'buckwheat flour', 'soy flour', 'gluten']
# ********************
# 13. 100  whole wheat pizza dough and pizza tips
# ['whole wheat flour', 'honey', 'salt', 'instant yeast', 'water', 'olive oil']
# ********************
# 14. 100  whole wheat  multipurpose dough   pizza  buns  bread
# ['whole wheat flour', 'water', 'table salt', 'instant yeast', 'cooking oil', 'honey']
# ********************
# 15. 2 minute pizza  or pastry crust
# ['all-purpose flour', 'baking soda', 'salt', 'oil', 'hot water']
# ********************
# 16. 2bleu s 2 minute 2 easy pizza sauce
# ['tomato sauce', 'tomato paste', 'italian seasoning', 'garlic powder', 'sugar', 'salt', 'crushed red pepper flakes', 'olive oil']
# ********************
# 17. 2bleu s pepperoni pizza burgers
# ['pepperoni', 'ground beef', 'mild italian sausage', 'butter', 'olive oil', 'sliced mushrooms', 'mozzarella cheese', 'provolone cheese', 'pizza sauce', 'kaiser rolls']
# ********************
# 18. 3 c s and a p pizza
# ['pizza dough', 'prosciutto', 'roasted red pepper', 'alfredo sauce', 'pizza sauce', 'fresh basil', 'mozzarella cheese', 'provolone cheese', 'gouda cheese']
# ********************
# 19. 3 ingredient individual quinoa pizza crust  no soaking
# ['quinoa', 'water', 'whole wheat flour', 'coconut oil']
# ********************
# 20. 3 meat breakfast pizza
# ['12-inch pizza crust', 'country gravy mix', 'milk', 'water', 'sausage links', 'ham', 'bacon bits', 'margarine', 'eggs', 'cheddar cheese']
# ********************
# 21. 4 layer pizza dip
# ['fat free cream cheese', 'fat free sour cream', 'mozzarella cheese', 'diced tomatoes', 'garlic powder', 'onion powder', 'italian seasoning', 'kosher salt', 'pepper', 'pepperoni', 'cooked bacon']
# ********************
# 22. 4 points   white pizza
# ['olive oil', 'vidalia onions', 'sugar', 'salt', 'spinach', 'part-skim ricotta cheese', 'parmesan cheese', 'fresh basil', 'pizza crusts']
# ********************
# 23. 4 square family pizza
# ['cornmeal', 'pillsbury refrigerated classic pizza crust', 'olive oil', 'cheddar cheese', 'mozzarella cheese', 'red onion', 'chicken', 'fresh parmesan cheese', 'plum tomatoes', 'basil', 'pizza sauce', 'canadian bacon', 'pineapple tidbits', 'pepperoni']
# ********************
# 24. 5 minute pita pizza
# ['pita breads', 'bolognese sauce', 'cheese']
# ********************
# 25. 5 minute artisan pizza dough
# ['water', 'olive oil', 'granulated yeast', 'kosher salt', 'unbleached all-purpose flour']
# ********************
# 26. 7 layer taco pizza
# ['pinto beans', 'fat free tortillas', 'salsa', 'romaine lettuce', 'low-fat cheddar cheese', 'tomatoes', 'scallions']
# ********************
# 27. 9 head garlic blast cheese pizza with shrimp
# ['garlic', 'water', 'salt', 'olive oil', 'ricotta cheese', 'egg', 'fontina cheese', 'parmesan cheese', 'basil pesto', 'boboli pizza crusts', 'sun-dried tomato', 'tomatoes', 'zucchini', 'small shrimp', 'mozzarella cheese']
# ********************
# 28. a different  pizza
# ['sausage', 'onion', 'flour', 'italian seasoning', 'salt', 'pepper', 'milk', 'eggs', 'pizza sauce', 'mozzarella cheese']
# ********************
# 29. a different kind of french bread pizza
# ['butter', 'flour', 'whole milk', 'salt and pepper', 'honey mustard', 'baguette', 'deli ham', 'gruyere', 'thyme', 'shallot', 'white wine vinegar', 'olive oil', 'english cucumber', 'radishes', 'frisee']
# ********************
# 30. a whole lotta pizza casserole
# ['egg noodles', 'vegetable oil', 'ground beef', 'onion', 'garlic clove', 'dried oregano', 'salt', 'condensed tomato soup', 'mozzarella cheese']
# ********************
# 31. aarsis ultimate peach and goat cheese pizza
# ['peaches', 'fresh goat cheese', 'honey', 'naan bread', 'olive oil', 'fresh ground black pepper']
# ********************
# 32. abm perfect pizza dough
# ['water', 'margarine', 'salt', 'ground black pepper', 'sugar', 'white flour', 'whole wheat flour', 'yeast']
# ********************
# 33. absolutely yummy vegetable pizza
# ['prepared pizza crust', 'cauliflower', 'broccoli', 'carrot', 'red bell pepper', 'mushroom', 'mozzarella cheese', 'cream cheese', 'ranch salad dressing', 'sour cream']
# ********************
# 34. accidental veggie tortilla  pizza
# ['whole wheat tortillas', 'part-skim mozzarella cheese', 'pizza sauce', 'fresh spinach', 'sweet red pepper', 'carrot', 'fresh tomato', 'cheddar cheese']
# ********************
# 35. acorn squash and arugula pizza
# ['acorn squash', 'red pepper flakes', 'olive oil', 'maple syrup', 'salt and pepper', 'gorgonzola', 'mozzarella cheese', 'arugula', 'oil', 'cracked pepper']
# ********************
# 36. addictive cheeseburger pizza
# ['lean hamburger', 'italian sausage', 'green pepper', 'onion', 'garlic', 'marinara sauce', 'mozzarella cheese', 'velveeta cheese', 'pizza dough']
# ********************
# 37. alfredo bacon chicken pizza
# ['pizza crust', 'alfredo sauce', 'cooked chicken breasts', 'bacon', 'artichoke hearts', 'baby spinach', 'sun-dried tomato', 'mozzarella cheese', 'asiago cheese', 'parmesan cheese', 'scallion']
# ********************
# 38. alfredo deep dish pizza
# ['warm water', 'vegetable oil', 'active dry yeast', 'all-purpose flour', 'heavy cream', 'butter', 'cream cheese', 'parmesan cheese', 'garlic powder', 'mozzarella cheese']
# ********************
# 39. alfredo prosciutto pizza
# ['pizza dough', 'prosciutto', 'green onions', 'alfredo sauce', 'fresh basil', 'monterey jack cheese', 'cornmeal']
# ********************
# 40. alfredo bacon  mushroom pizza  best pizza ever
# ['alfredo sauce', 'mushroom', 'pizza dough', 'bacon', 'mozzarella cheese']
# ********************
# 41. all american cheeseburger pizza
# ['cooked ground beef', 'ketchup', 'mustard', 'caramelized onion', 'cheddar cheese', 'mozzarella cheese', 'tomatoes', 'dill pickle slices', 'pizza dough', 'romaine lettuce', 'thousand island dressing', 'onion', 'kosher salt', 'vegetable oil', 'fresh ground black pepper', 'sugar']
# ********************
# 42. all american ranch spinach shrimp pizza  rsc
# ['pizza dough', 'oil', 'hidden valley original ranch dressing and seasoning mix', 'olive oil', 'shallot', 'baby spinach', 'roasted garlic cloves', 'sun-dried tomatoes packed in oil with herbs', 'shrimp', 'smoked paprika', 'cracked black pepper', 'oregano', 'cheese', 'parmesan cheese', 'sour cream']
# ********************
# 43. all american pizza crust
# ['all-purpose flour', 'fast rise yeast', 'salt', 'water', 'vegetable oil']
# ********************
# 44. almost like papa john s pizza dough
# ['flour', 'sugar', 'fast rising yeast', 'salt', 'water', 'oil']
# ********************
# 45. almost like you re in heaven it  so good pizza quesadillas
# ['tortillas', 'pizza sauce', 'pepperoni', 'mozzarella cheese', 'parmesan cheese', 'basil']
# ********************
# 46. aloha pizza
# ['pizza dough', 'extra virgin olive oil', 'salt & pepper', 'mozzarella cheese', 'pineapple', 'onion', 'prosciutto', 'frisee']
# ********************
# 47. alouette baby brie caramelized pepper   onion pizza
# ['prepared pizza crust', 'brie cheese', 'yellow onions', 'balsamic vinaigrette', 'brown sugar', 'roasted red pepper', 'olive oil', 'fresh thyme leave']
# ********************
# 48. alton brown s pizza
# ['sugar', 'kosher salt', 'pure olive oil', 'warm water', 'bread flour', 'instant yeast', 'olive oil', 'flour', 'pizza sauce', 'fresh herb', 'mozzarella cheese']
# ********************
# 49. amazing breakfast pizza
# ['pizza dough', 'eggs', 'milk', 'cheddar cheese', 'mozzarella cheese', 'deli ham', 'cooked bacon', 'breakfast sausage links', 'onion', 'chives']
# ********************
# 50. amazing homemade pizza rolls
# ['pizza cheese', 'sausage', 'pepperoni', 'green pepper', 'sliced mushrooms', 'onion', 'black olives', 'crushed pineapple', 'pizza sauce', 'egg roll wraps', 'oil']
# ********************
# 51. amazing ny style white garlic pizza
# ['pizza crust', 'italian sausage', 'garlic alfredo sauce', 'onion', 'italian cheese blend']
# ********************
# 52. amazing thin crust pizza
# ['bread flour', 'instant yeast', 'salt', 'olive oil', 'warm water', 'crushed tomatoes', 'minced garlic cloves', 'oregano', 'ground fennel', 'salt and pepper', 'recipe pizza dough', 'dried basil', 'mozzarella cheese', 'provolone cheese', 'tomato sauce', 'sausage', 'mild cheddar cheese']
# ********************
# 53. america s test kitchen thin crust pizza
# ['bread flour', 'sugar', 'fast rising yeast', 'ice water', 'vegetable oil', 'salt', 'whole canned tomatoes', 'extra virgin olive oil', 'red wine vinegar', 'garlic cloves', 'dried oregano', 'black pepper', 'parmesan cheese', 'whole milk mozzarella']
# ********************
# 54. amy s fruit pizza
# ['refrigerated sugar cookie dough', 'cream cheese', 'cool whip', 'marshmallow creme', 'fresh fruit', 'sugar', 'salt', 'cornstarch', 'orange juice', 'lemon juice', 'water']
# ********************
# 55. amy s pizza dip
# ['oregano', 'cream cheese', 'pepperoni slice', 'green onion', 'sour cream', 'pizza sauce', 'bell pepper', 'mozzarella cheese', 'pita chips']
# ********************
# 56. amy s upside down pizza
# ['ground chuck', 'onion', 'garlic', 'spaghetti sauce', 'mozzarella cheese', 'parmesan cheese', 'crescent rolls']
# ********************
# 57. an aussie vegemite pizza
# ['prepared pizza crust', 'vegemite', 'ham', 'onion', 'tasty cheese', 'eggs']
# ********************
# 58. an italian s classic pizza dough
# ['salt', 'honey', 'olive oil', 'water', 'active dry yeast', 'warm water', 'flour', 'butter']
# ********************
# 59. andrea s fruit pizza
# ['kiwi fruits', 'strawberry', 'apples', 'whipped cream cheese', 'sugar', 'milk', 'refrigerated sugar cookie dough', 'grapes']
# ********************
# 60. andy s pizza dip
# ['velveeta cheese', 'cream cheese', 'pizza sauce']
# ********************
# 61. ange s awesome pizza base
# ['flour', 'salt', 'yeast', 'hot water']
# ********************
# 62. ange s pizza sauce
# ['sun-dried tomatoes', 'garlic', 'fresh basil']
# ********************
# 63. annika s pizza   pasta sauce
# ['tomatoes', 'diced tomatoes', 'juice', 'onion', 'garlic', 'basil', 'thyme', 'oregano', 'brown sugar', 'tomato paste']
# ********************
# 64. annz california fuzion pizza
# ['pizza crusts', 'pesto sauce', 'chicken', 'sweet onion', 'green chili pepper', 'blue cheese', 'italian cheese blend', 'fresh tomato']
# ********************
# 65. another easy pizza sauce
# ['whole tomatoes', 'olive oil', 'salt', 'red pepper flakes', 'dried oregano', 'dried basil']
# ********************
# 66. anthony s french bread pizza
# ['french bread', 'pizza sauce', 'mozzarella cheese', 'pepperoni slices']
# ********************
# 67. antipasto pizza
# ['pita pockets', 'pizza sauce', 'parmesan cheese', 'salami', 'eggplants', 'artichoke hearts', 'roasted red peppers', 'kalamata olive', 'mozzarella cheese', 'basil leaves']
# ********************
# 68. anytime pizza casserole
# ['ground beef', 'onion', 'vegetable oil', 'garlic powder', 'mozzarella cheese', 'onion powder', 'spaghetti sauce', 'cooked macaroni', 'pepperoni']
# ********************
# 69. aphrodite s faster than takeout pizza
# ['eggplant', 'red pepper', 'red onion', 'balsamic vinegar', 'olive oil', 'garlic', 'sherry wine', 'sugar', 'tahini', 'flat bread', 'kalamata olives', 'feta cheese', 'parmesan cheese']
# ********************
# 70. apple  pizza   weight watchers points   5
# ['light butter', 'apples', 'sugar', 'cinnamon', 'yellow cake mix', 'nonfat milk', 'fat free cream cheese', 'old fashioned oats', 'all-purpose flour', 'brown sugar']
# ********************
# 71. apple and spice pizza cookies
# ['margarine', 'sugar', 'egg', 'flour', 'cinnamon', 'apple', 'oats', 'brown sugar', 'vanilla', 'baking soda', 'salt', 'butterscotch chips', 'powdered sugar', 'milk']
# ********************
# 72. apple pizza
# ['pastry for double-crust pie', 'apples', 'flour', 'brown sugar', 'cinnamon', 'butter', 'powdered sugar', 'milk', 'caramel flavoring', 'peanuts']
# ********************
# 73. apple pizza pie
# ['flour', 'salt', 'shortening', 'cheddar cheese', 'water', 'non-dairy powdered coffee creamer', 'brown sugar', 'white sugar', 'cinnamon', 'nutmeg', 'butter', 'apples', 'lemon juice']
# ********************
# 74. apple  honey   caramelized onion flatbread pizza
# ['prepared pizza crust', 'olive oil', 'yellow onions', 'dried rosemary', 'salt', 'pepper', 'cornmeal', 'granny smith apples', 'brie cheese', 'mozzarella cheese', 'parmesan cheese', 'honey', 'parsley']
# ********************
# 75. apple anise pizza
# ['boboli pizza crusts', 'shallots', 'olive oil', 'granny smith apples', 'walnuts', 'honey', 'anise seed', 'swiss cheese']
# ********************
# 76. apple cheddar brunch pizza
# ['flour', 'bread dough', 'tart apples', 'brown sugar', 'white sugar', 'apple pie spice', 'nutmeg', 'butter', 'cheddar cheese']
# ********************
# 77. apple cheese english muffin pizzas
# ['english muffins', 'apple', 'cheddar cheese', 'cream cheese', 'dried cranberries']
# ********************
# 78. applebee s veggie patch pizza
# ['flour tortillas', 'butter-flavored oil', 'sliced mushrooms', 'black pepper', 'granulated garlic', 'salt', 'italian seasoning', 'diced tomato', 'mozzarella cheese', 'parmesan cheese', 'frozen chopped spinach', 'artichoke hearts', 'alfredo sauce', 'garlic', 'cream cheese']
# ********************
# 79. approximately  aurelio s pizza and pasta sauce
# ['tomato puree', 'beer', 'white sugar', 'garlic powder', 'dried basil', 'dried oregano', 'salt']
# ********************
# 80. armenian pizza   lahmajoun
# ['ground lamb', 'green pepper', 'onion', 'parsley', 'minced garlic clove', 'crushed tomatoes', 'cumin', 'salt', 'crushed red pepper flakes', 'black pepper', 'mint', 'tortillas']
# ********************
# 81. artichoke and red pepper pizza
# ['boboli thin pizza shell', 'olive oil', 'red bell pepper', 'dried basil', 'dried oregano', 'garlic', 'artichoke hearts', 'mushrooms', 'part-skim mozzarella cheese', 'fresh cracked pepper']
# ********************
# 82. artichoke pizza
# ['black olives', 'marinated artichokes', 'chestnut mushrooms', 'mozzarella cheese', 'tomato sauce', 'prepared pizza crust']
# ********************
# 83. artichoke sun dried tomato pizza
# ['warm water', 'yeast', 'sugar', 'salt', 'olive oil', 'flour', 'garlic', 'dried italian herb seasoning', 'tomato sauce', 'oregano', 'mixed italian herbs', 'black pepper', 'red pepper flakes', 'garlic powder', 'marinated artichoke hearts', 'onion', 'mushrooms', 'black olives', 'sun-dried tomatoes', 'hot water', 'soy mozzarella cheese', 'cooking spray']
# ********************
# 84. artichoke  olive and goat s cheese pizza
# ['prepared pizza crust', 'pasta sauce', 'marinated artichokes', 'kalamata olives', 'garlic clove', "goat's cheese", 'olive oil', 'fresh oregano']
# ********************
# 85. artichoke  pesto   sun dried tomato pizza with three cheeses
# ['pizza dough', 'mozzarella cheese', 'parmesan cheese', 'chicken breast', 'artichoke hearts', 'sun-dried tomato', 'ricotta cheese', 'red pepper flakes', 'basil pesto']
# ********************
# 86. arugula and walnut pizza
# ['olive oil', 'garlic clove', 'boboli whole wheat pizza crust', 'baby arugula', 'goat cheese', 'walnuts', 'balsamic vinegar']
# ********************
# 87. arugula blt pizzas
# ['marinara sauce', 'whole grain english muffins', 'arugula leaf', 'tomatoes', 'turkey bacon', 'part-skim mozzarella cheese']
# ********************
# 88. arugula  caramelized onion and goat cheese pizza
# ['olive oil', 'red onion', 'baby arugula', 'salt and pepper', 'whole wheat tortillas', 'goat cheese']
# ********************
# 89. asparagus pizza
# ['pizza dough', 'asparagus', 'olive oil', 'salt', 'pepper', 'garlic cloves', 'fontina cheese', 'parmesan cheese']
# ********************
# 90. astonishingly easy  yeasty  bisquick pizza dough
# ['biscuit mix', 'whole wheat flour', 'warm water', 'yeast', 'olive oil']
# ********************
# 91. atk s grandma pizza
# ['olive oil', 'water', 'bread flour', 'yeast', 'sugar', 'salt', 'diced tomatoes', 'garlic cloves', 'dry oregano', 'mozzarella cheese', 'parmesan cheese', 'fresh basil']
# ********************
# 92. atsa spicy pizza sausage
# ['lean ground beef', 'ground pork', 'dry red wine', 'fresh parsley', 'parmesan cheese', 'fennel seed', 'crushed red pepper flakes', 'salt', 'dried thyme', 'fresh ground black pepper', 'garlic']
# ********************
# 93. auberge chorizo  goat s cheese and onion pizza   thin crust
# ['dry yeast', 'sugar', 'water', 'bread flour', 'salt', 'chorizo sausage', "goat's cheese", 'red onion', 'tomatoes', 'tomato paste', 'capers', 'sun-dried tomatoes packed in oil', 'mozzarella cheese', 'fresh ground black pepper', 'oregano']
# ********************
# 94. aunt alta s crazy crust pizza
# ['all-purpose flour', 'salt', 'oregano', 'black pepper', 'eggs', 'skim milk', 'tomato sauce', 'garlic powder', 'red pepper flakes', 'italian sausage', 'onion', 'green bell pepper', 'mushrooms', 'fresh garlic', 'mozzarella cheese']
# ********************
# 95. authentic pizza dough  bulk
# ['hi-gluten flour', 'honey', 'active dry yeast', 'water', 'sea salt']
# ********************
# 96. avocado pizza
# ['pizza crusts', 'tomato paste', 'garlic clove', 'green onion', 'mushroom', 'olive', 'cherry tomatoes', 'reduced-fat mozzarella cheese', 'basil leaves', 'avocado']
# ********************
# 97. award winning pizza
# ['pizza dough', 'heavy cream', 'mozzarella cheese', 'pancetta', 'zucchini', 'cream cheese']
# ********************
# 98. awesome bread machine pizza dough
# ['water', 'olive oil', 'salt', 'parmesan cheese', 'cornmeal', 'bread flour', 'dry yeast']
# ********************
# 99. awesome grilled pizza
# ['bread flour', 'whole wheat flour', 'sugar', 'salt', 'fast rising yeast', 'water', 'extra virgin olive oil', 'oil', 'minced garlic cloves', 'red pepper flakes', 'roma tomatoes', 'fontina', 'parmesan cheese', 'fresh basil']
# ********************
# 100. awesome white pizza dip
# ['low-fat sour cream', 'part-skim ricotta cheese', 'reduced-fat mozzarella cheese', 'herb with garlic soup mix', 'red pepper flakes']
# ********************
# 101. b b q chicken pizza
# ['pizza dough', 'barbecued chicken', 'italian cheese blend', 'fresh cilantro', 'pepper sauce']
# ********************
# 102. b l t pizza
# ['prepared pizza crust', 'cream cheese', 'italian seasoning', 'fresh ground black pepper', 'lettuce', 'colby-monterey jack cheese', 'tomatoes', 'bacon', 'sliced ripe olives']
# ********************
# 103. babzy s easy  no cook pizza sauce
# ['tomato paste', 'boiling water', 'garlic clove', 'oregano', 'basil', 'onion powder', 'sugar', 'pepper', 'salt', 'parmesan cheese']
# ********************
# 104. bacon and egg pizza
# ['refrigerated crescent dinner roll', 'bacon', 'frozen hash brown potatoes', 'cheese', 'eggs', 'milk', 'parmesan cheese']
# ********************
# 105. bacon cheeseburger pizza
# ['ground beef', 'onion', 'garlic', 'seasoning salt', 'black pepper', 'parmesan cheese', 'pizza sauce', 'mozzarella cheese', 'cheddar cheese', 'bacon']
# ********************
# 106. bacon cheeseburger upside down pizza
# ['lean ground beef', 'onion', 'bell pepper', 'bacon', 'pizza sauce', 'italian plum tomatoes', 'cheddar cheese', 'eggs', 'milk', 'oil', 'all-purpose flour', 'salt']
# ********************
# 107. bacon county  georgia peachy pizza  rsc
# ['extra virgin olive oil', 'onion', 'crushed tomatoes', 'garlic cloves', 'salt', 'black pepper', 'crushed red pepper flakes', 'lemon zest', 'bread flour', 'instant yeast', 'olive oil', 'warm water', 'sea salt', 'fresh mozzarella cheese', 'peaches', 'smoked bacon', 'goat cheese', 'cream cheese', 'nonstick cooking spray', 'reynolds wrap foil']
# ********************
# 108. bacon jam and potato breakfast pizza  sp5
# ['pizza dough', 'simply potatoes shredded hash browns', 'jam', 'mozzarella cheese', 'eggs']
# ********************
# 109. bacon  cheddar  and tomato pita pizzas
# ['bacon', 'whole wheat pita bread', 'olive oil', 'dried basil', 'red onions', 'tomatoes', 'cheddar cheese', 'pepper']
# ********************
# 110. bacon  tomato   spinach pizza
# ['frozen pizza dough', 'alfredo sauce', 'mozzarella cheese', 'frozen chopped spinach', 'plum tomatoes', 'cooked bacon']
# ********************
# 111. bacon cheeseburger pizza
# ['all-purpose flour', 'active dry yeast', 'salt', 'warm water', 'cooking oil', 'onion', 'garlic cloves', 'olive oil', 'tomatoes', 'tomato sauce', 'bay leaf', 'fresh basil', 'fresh oregano', 'fennel seed', 'sugar', 'pepper', 'ground beef', 'bacon', 'cheddar cheese']
# ********************
# 112. badda bing pizza with pesto esque sauce
# ['pizza crust', 'onion', 'sliced mushrooms', 'elephant garlic', 'baby spinach leaves', 'cheese', 'tomatoes', 'black olives', 'pine nuts', 'fresh oregano', 'black pepper', 'fresh basil leaves', 'olive oil']
# ********************
# 113. bagel pizza
# ['bagel', 'deli ham', 'pepperoni', 'provolone cheese']
# ********************
# 114. bagel pizzas  oamc
# ['bagels', 'ground beef', 'onion', 'salt', 'pepper', 'garlic salt', 'cheese spread', 'pizza sauce', 'fresh parsley', 'parmesan cheese']
# ********************
# 115. baked bean pizza
# ['baked beans', 'coarse grain mustard', 'barbecue sauce', 'ham', 'cheese', 'prepared pizza crust']
# ********************
# 116. baked macaroni   cheese with pizzazz
# ['shell noodles', 'butter', 'condensed cheddar cheese soup', 'evaporated milk', 'chicken bouillon cube', 'season-all salt', 'onion powder', 'black pepper', 'dry mustard', 'sharp cheddar cheese']
# ********************
# 117. baked pepperoni pizza dip
# ['cream cheese', 'sour cream', 'dried oregano', 'garlic', 'pizza sauce', 'pepperoni', 'green onions', 'mozzarella cheese', 'parmesan cheese']
# ********************
# 118. baked pizza burgers
# ['ground beef', 'onion', 'dried oregano', 'pizza sauce', 'shredded cheddar cheese', 'hamburger buns']
# ********************
# 119. baked pizza dip
# ['cream cheese', 'italian seasoning', 'mozzarella cheese', 'pizza sauce', 'pepperoni', 'parmesan cheese', 'soft breadsticks']
# ********************
# 120. baked pizza mac
# ['pizza sauce', 'macaroni & cheese dinner mix', 'ground beef', 'egg', 'dried basil leaves', 'garlic powder', 'mozzarella cheese']
# ********************
# 121. baked pizza potato skins
# ['potatoes', 'oil', 'pizza sauce', 'green pepper', 'canned mushroom', 'mozzarella cheese']
# ********************
# 122. baked pizza sandwich
# ['lean ground beef', 'oregano leaves', 'tomato sauce', 'egg', 'biscuit mix', 'american cheese', 'milk', 'parmesan cheese', 'mushrooms']
# ********************
# 123. baked pizza steak
# ['all-purpose flour', 'salt', 'beef cube steaks', 'olive oil', 'mushrooms', 'onion', 'pizza sauce', 'part-skim mozzarella cheese']
# ********************
# 124. baked potato pizza
# ['prepared pizza crust', 'potatoes', 'margarine', 'garlic powder', 'dried italian seasoning', 'sour cream', 'bacon', 'green onion', 'mozzarella cheese', 'cheddar cheese']
# ********************
# 125. baked ziti pizza
# ['pizza crust', 'diced tomatoes', 'dried basil', 'dried parsley', 'dried oregano', 'ziti pasta', 'ricotta cheese', 'mozzarella cheese', 'parmesan cheese']
# ********************
# 126. balsamic onions  asparagus    goat cheese pizza
# ['olive oil', 'onion', 'garlic clove', 'balsamic vinegar', 'granulated sugar', 'asparagus', 'tomatoes', 'dried basil', 'salt and pepper', 'whole wheat pizza crust', 'goat cheese']
# ********************
# 127. balsamic tomato and garlic pizza with walnuts
# ['pizza dough', 'tomatoes', 'balsamic vinegar', 'kosher salt', 'fresh garlic cloves', 'walnuts', 'mozzarella cheese', 'feta cheese', 'olive oil']
# ********************
# 128. banana toffee pizza
# ['refrigerated sugar cookie dough', 'cream cheese', 'brown sugar', 'frozen whipped topping', 'chocolate-covered english toffee bars', 'toasted sliced almonds', 'bananas', 'caramel ice cream topping']
# ********************
# 129. banana berry brownie pizza
# ['brownie mix', 'water', 'vegetable oil', 'egg', 'cream cheese', 'sugar', 'vanilla extract', 'strawberries', 'firm banana', 'semisweet chocolate']
# ********************
# 130. bar b q chicken pizza
# ['thin pizza crust', 'hickory flavored barbecue sauce', 'red peppers', 'yellow peppers', 'chicken breasts', 'monterey jack cheese']
# ********************
# 131. barbecue cashew chicken pizza with french fried onions
# ['prepared pizza crust', 'barbecue sauce', 'grape jelly', 'pepper', 'sweet onion', 'cooked chicken breasts', 'cashew halves', 'fresh cilantro', 'mozzarella cheese', 'french-fried onions', 'fresh cilantro stems']
# ********************
# 132. barbecue chicken and black bean pizza
# ['boneless skinless chicken breast', 'barbecue sauce', 'pizza dough', 'cheddar cheese', 'canned black beans', 'red onion', 'cilantro']
# ********************
# 133. barbecue chicken pizza
# ['chicken breast halves', 'hickory flavored barbecue sauce', 'gruyere cheese', 'boboli pizza crusts', 'red onion', 'green onion', 'fresh cilantro']
# ********************
# 134. barbecue or oven baked pizza bread
# ['french bread', 'lean ground beef', 'tomato paste', 'white sugar', 'stuffed olives', 'fresh parmesan cheese', 'fresh chives', 'salt', 'dried oregano', 'pepper', 'mozzarella cheese']
# ********************
# 135. barbecued chicken pizza
# ['red onion', 'garlic cloves', 'turkey bacon', 'chicken breast', 'red pepper', 'green pepper', 'seasoning', 'dried chipotle powder', 'fresh black pepper', 'green chili', 'reduced-fat cream cheese', 'barbecue sauce', 'reduced-fat mexican cheese blend', 'fresh cilantro', 'thin pizza crust']
# ********************
# 136. barbecued chicken tortilla pizzas
# ['flour tortillas', 'barbecued chicken', 'chopped tomato', 'monterey jack pepper cheese', 'salsa']
# ********************
# 137. basic cheese pizza
# ['dry yeast', 'water', 'sugar', 'bread flour', 'salt', 'olive oil', 'tomato puree', 'tomato paste', 'garlic clove', 'fresh basil', 'fresh mozzarella cheese']
# ********************
# 138. basic pizza dough
# ['strong white flour', 'salt', 'dried yeast', 'olive oil', 'water', 'oregano']
# ********************
# 139. basic pizza dough  bread machine
# ['water', 'olive oil', 'flour', 'salt', 'sugar', 'bread machine yeast']
# ********************
# 140. basic pizza dough  italian
# ['dried yeast', 'water', 'sugar', 'flour', 'salt', 'olive oil']
# ********************
# 141. basic pizza dough  use now or use later  oamc too
# ['all-purpose flour', 'salt', 'active dry yeast', 'warm water', 'cornmeal']
# ********************
# 142. basic pizza sauce
# ['tomato sauce', 'oregano', 'basil leaves', 'garlic powder']
# ********************
# 143. basic quick pizza dough
# ['water', 'honey', 'olive oil', 'dry yeast', 'whole wheat flour', 'salt', 'unbleached all-purpose flour', 'cornmeal']
# ********************
# 144. basic simple pizza crust
# ['flour', 'yeast', 'salt', 'hot water', 'olive oil', 'cornmeal']
# ********************
# 145. basil   garlic pizza dough  abm
# ['water', 'olive oil', 'salt', 'all-purpose flour', 'bread machine yeast', 'basil', 'fresh garlic', 'parmesan cheese', 'cornmeal']
# ********************
# 146. basil bread slice pizzas
# ['italian bread', 'mozzarella cheese', 'fresh basil', 'cream cheese', 'tomato paste', 'italian seasoning']
# ********************
# 147. bbq chicken and blue cheese pizza
# ['thin pizza crust', 'barbecue sauce', 'chicken breasts', 'red onion', 'yellow bell pepper', 'blue cheese', 'plum tomatoes']
# ********************
# 148. bbq chicken deluxe pan pizza
# ['milk', 'butter', 'granulated sugar', 'salt', 'dry yeast', 'all-purpose flour', 'water', 'boneless skinless chicken breast', 'barbecue sauce', 'mozzarella cheese', 'bacon', 'pineapple', 'jalapeno pepper']
# ********************
# 149. bbq chicken french bread pizza
# ['red onion', 'margarine', 'brown sugar', 'catsup', 'hot water', 'dijon mustard', 'maple syrup', 'fresh lemon juice', 'cooked chicken breasts', 'french bread', 'provolone cheese']
# ********************
# 150. bbq chicken pizza
# ['chicken breasts', 'onion', 'barbecue sauce', 'prepared pizza crust', 'tomatoes', 'garlic', 'dry basil', 'olive oil', 'four-cheese mexican blend cheese', 'tomato paste', 'salt']
# ********************
# 151. bbq chicken pizza  weight watchers 5 pts per slice
# ['boboli whole wheat pizza crust', 'chicken', 'barbecue sauce', 'lowfat mozzarella cheese', 'fat-free cheddar cheese', 'cheddar cheese', 'red onion']
# ********************
# 152. bbq chicken pizza   california pizza kitchen style
# ['boneless skinless chicken breasts', 'olive oil', 'barbecue sauce', 'pizza dough', 'cornmeal', 'smoked gouda cheese', 'mozzarella cheese', 'red onion', 'fresh cilantro']
# ********************
# 153. bbq chicken pizza   california pizza kitchen style made over
# ['boneless skinless chicken breasts', 'low-calorie barbecue sauce', 'pizza dough', 'lowfat mozzarella cheese', 'red onion', 'fresh cilantro']
# ********************
# 154. bbq chicken pizza bites
# ['biscuits', 'chicken breasts', 'garlic', 'sliced mushrooms', 'diced tomatoes', 'seasoning', 'barbecue sauce', 'green onion', 'mozzarella cheese']
# ********************
# 155. bbq chicken pizza with feta
# ['prepared pizza crust', 'mozzarella cheese', 'grilled chicken breast', 'barbecue sauce', 'feta cheese', 'red onion']
# ********************
# 156. bbq pork pizza
# ['sweet onion', 'barbecued pork', 'whole wheat pizza crust', 'cheddar cheese', 'jalapeno pepper']
# ********************
# 157. bbq smokie pizza
# ['prepared pizza crust', 'barbecue sauce', 'little smokies sausages', 'pre-shredded mozzarella cheese', "o'brien frozen potatoes", 'tomatoes', 'onion', 'green pepper']
# ********************
# 158. bbq style chick pizza pie
# ['thin pizza crust', 'chicken breast', 'barbecue sauce', 'provel cheese']
# ********************
# 159. bbq d cheeseburger pizza
# ['whole wheat pizza dough', 'barbecue sauce', 'ground beef', 'garlic powder', 'dried parsley flakes', 'yellow mustard', 'diced onion', 'diced tomato', 'dill pickle', 'lettuce', 'mayonnaise', 'french dressing', 'dill relish', 'mozzarella cheese', 'cheddar cheese']
# ********************
# 160. bbq d cornmeal crust pizza with artichokes
# ['whole wheat flour', 'white flour', 'cornmeal', 'baking powder', 'baking soda', 'salt', 'dry basil', 'plain yogurt', 'lite olive oil', 'tomatoes', 'marinated artichoke hearts', 'black olives', 'green onions', 'mozzarella cheese', 'provolone cheese', 'fresh basil']
# ********************
# 161. bea s absolute favorite pizza sauce
# ['tomato paste', 'bacon drippings', 'garlic salt', 'oregano', 'basil', 'parmesan cheese', 'tomato juice']
# ********************
# 162. bea s buffalo chicken and blue cheese pizza
# ['pizza dough', "frank's red hot sauce", 'butter', 'chicken', 'onion', 'blue cheese', 'mozzarella cheese', 'ranch dressing']
# ********************
# 163. bea s pizza dough
# ['warm water', 'fast rising yeast', 'all-purpose flour', 'bacon drippings', 'salt']
# ********************
# 164. bean salad pizzazz
# ['green beans', 'wax beans', 'kidney beans', 'red onion', 'jalapeno peppers', 'grape tomatoes', 'lemon, juice of', 'white wine vinegar', 'vegetable oil', 'salt', 'ground black pepper', 'brown sugar', 'sugar', 'dijon mustard']
# ********************
# 165. beef macaroni pizza
# ['lean ground beef', 'seasoning salt', 'black pepper', 'egg', 'soft breadcrumbs', 'meatless sauce', 'elbow macaroni', 'salt', 'celery', 'parsley', 'sharp cheddar cheese', 'parmesan cheese', 'green pepper ring', 'oil']
# ********************
# 166. beef or veal alla pizzaiola
# ['chuck steaks', 'olive oil', 'salt', 'pepper', 'garlic', 'fresh italian parsley', 'oregano', 'onion', 'white button mushrooms', 'green pepper', 'italian plum tomatoes']
# ********************
# 167. beef pizza casserole  with pizza crust
# ['ground beef', 'dried chili pepper flakes', 'onions', 'garlic', 'green bell pepper', 'dried italian seasoning', 'seasoning salt', 'pepper', 'parmesan cheese', 'flour', 'pasta sauce', 'sliced mushrooms', 'mozzarella cheese', 'prepared pizza crust', 'olive oil']
# ********************
# 168. beef pizzaiola
# ['beef sirloin', 'stewed tomatoes', 'garlic', 'fresh basil', 'oregano', 'cracked pepper', 'olive oil']
# ********************
# 169. beefy pizza casserole
# ['ground beef', 'onions', 'green bell pepper', 'dried italian seasoning', 'all-purpose flour', 'tomato and basil pasta sauce', 'mozzarella cheese', 'prepared pizza crust', 'olive oil', 'parmesan cheese']
# ********************
# 170. beer dough pizza
# ['flour', 'active dry yeast', 'sugar', 'beer', 'italian style breadcrumbs']
# ********************
# 171. beer pizza
# ['pepperoni', 'bacon', 'mushrooms', 'onion', 'green pepper', 'mozzarella cheese', 'tomato sauce', 'garlic', 'oregano', 'thyme', 'salt', 'beer', 'olive oil', '15 inch pizza crusts']
# ********************
# 172. beer pizza crust
# ['beer', 'salt', 'granulated sugar', 'all-purpose flour', 'dried basil', 'bread machine yeast']
# ********************
# 173. beer pizza dough  for black and decker bread machine
# ['beer', 'shortening', 'sugar', 'salt', 'white flour', 'dry yeast']
# ********************
# 174. beet   onion pizza w goat cheese
# ['cooked beets', 'yellow sweet onion', 'garlic clove', 'butter', 'goat cheese', 'fontina cheese', 'pizza dough']
# ********************
# 175. berks county bread machine pizza crust
# ['water', 'olive oil', 'flour', 'salt', 'active dry yeast']
# ********************
# 176. berry patch brownie pizza
# ['fudge brownie mix', 'almonds', 'cream cheese', 'granulated sugar', 'vanilla', 'frozen whipped topping', 'fresh strawberries', 'raspberries', 'fresh blueberries', 'lemon', 'powdered sugar', 'strawberry']
# ********************
# 177. berry patch brownie pizza
# ['fudge brownie mix', 'almonds', 'almond extract', 'cream cheese', 'sugar', 'vanilla extract', 'lemon peel', 'whipped topping', 'berries']
# ********************
# 178. best bread machine pizza dough
# ['water', 'olive oil', 'salt', 'dried oregano', 'all-purpose flour', 'bread flour', 'yeast']
# ********************
# 179. best ever pizza crust    bread machine
# ['plain flour', 'dry yeast', 'water', 'olive oil', 'parmesan cheese', 'garlic clove', 'mixed italian herbs']
# ********************
# 180. best pizza dip
# ['cream cheese', 'sour cream', 'marinara sauce', 'mozzarella cheese', 'parmesan cheese', 'italian seasoning', 'onion powder', 'garlic', 'pepperoni']
# ********************
# 181. best pizza dough
# ['flour', 'yeast', 'warm water', 'salt', 'oil']
# ********************
# 182. best pizza margherita
# ['pizza dough', 'san marzano tomatoes', 'dried oregano', 'extra virgin olive oil', 'salt & freshly ground black pepper', 'buffalo mozzarella', 'basil leaves']
# ********************
# 183. beth s pizza crust
# ['yeast', 'water', 'flour', 'olive oil', 'sugar', 'salt']
# ********************
# 184. better than frozen french bread pizza
# ['french bread', 'spaghetti sauce', 'dried oregano', 'green pepper', 'fresh mushrooms', 'fat-free parmesan cheese', 'lowfat mozzarella cheese']
# ********************
# 185. biancoverde  greens on white  pizza
# ['prepared pizza crust', 'garlic paste', 'mozzarella cheese', 'asiago cheese', 'part-skim ricotta cheese', 'white truffle oil', 'arugula', 'olive oil', 'salt', 'fresh ground pepper']
# ********************
# 186. big kahuna personal pizza
# ['hot dogs', 'pizza sauce', 'cheddar cheese', 'mozzarella cheese', 'pepperoni']
# ********************
# 187. bird s pizza style lasagna
# ['olive oil', 'ground sausage', 'garlic cloves', 'italian seasoning', 'crushed red pepper flakes', 'green bell pepper', 'spaghetti sauce', 'mozzarella cheese', 'shredded cheddar cheese', 'parmesan cheese', 'lasagna noodle', 'pepperoni', 'fresh mushrooms', 'onion']
# ********************
# 188. biscuit mix pizza dough
# ['yeast', 'water', 'biscuit mix']
# ********************
# 189. bisquick pizza pull apart bread
# ['tomatoes', 'bisquick', 'mozzarella cheese', 'milk', 'bell pepper', 'onion', 'pepperoni', 'pizza sauce', 'oil']
# ********************
# 190. bistecca alla pizzaiola  steak with the pizzaiolos wifes sauce
# ['beef t-bone steaks', 'salt and pepper', 'extra virgin olive oil', 'garlic cloves', 'tomatoes', 'red pepper flakes', 'fresh oregano', 'white wine']
# ********************
# 191. bistro onion jalapeno pizza
# ['onion', 'butter', 'olive oil', 'garlic', 'white sugar', 'jalapeno peppers', 'seasoning salt', 'black pepper', 'half-and-half cream', 'egg', 'gruyere', 'prepared pizza crust']
# ********************
# 192. black forest pizza
# ['brownie mix', 'cream cheese', "confectioners' sugar", 'frozen whipped topping', 'cherry pie filling', 'chocolate sprinkles']
# ********************
# 193. black bean pizza dough recipe
# ['active dry yeast', 'bread flour', 'salt', 'water', 'cayenne pepper', 'black beans']
# ********************
# 194. bld carbonara pizza   rachael ray
# ['cornmeal', 'pizza dough', 'extra virgin olive oil', 'pancetta', 'ricotta cheese', 'pecorino romano cheese', 'egg yolks', 'garlic clove', 'pepper', 'provolone cheese', 'flat leaf parsley']
# ********************
# 195. bliss chicken pizza
# ['prepared pizza crust', 'sugar', 'soy sauce', 'garlic', 'jalapeno', 'chicken breasts', 'salt & pepper', 'olive oil', 'butter', 'meat seasoning', 'poultry seasoning', 'onion', 'red pepper', 'canned corn', 'green onion', 'cheese']
# ********************
# 196. blt  bacon  lettuce   tomato  pizza
# ['pizza crust', 'mozzarella cheese', 'extra virgin olive oil', 'bacon', 'roma tomatoes', 'lettuce', 'tzatziki']
# ********************
# 197. blt pizza
# ['mayonnaise', 'dried basil', 'garlic powder', 'onion powder', 'prepared pizza crust', 'bacon', 'cheddar cheese', 'mozzarella cheese', 'lettuce', 'tomatoes']
# ********************
# 198. blt ranch salad pizza   pampered chef
# ['pillsbury refrigerated classic pizza crust', 'iceberg lettuce', 'plum tomatoes', 'cream cheese', 'ranch dressing', 'garlic clove', 'cheddar cheese', 'olive', 'onion', 'bacon']
# ********************
# 199. blue cheese and caramelised onion pizza
# ['onions', 'butter', 'balsamic vinegar', 'brown sugar', 'thin pizza crust', 'roasted garlic', 'blue cheese', 'sun-dried tomatoes']
# ********************
# 200. blueberry cheesecake pizza
# ['all-purpose flour', 'powdered sugar', 'butter', 'cream cheese', 'sweetened condensed milk', 'lemon juice', 'vanilla extract', 'granulated sugar', 'cornstarch', 'water', 'blueberries']
# ********************
# 201. blueberry dessert pizza
# ['yellow cake mix', 'quick-cooking rolled oats', 'butter', 'egg', 'nuts', 'brown sugar', 'cinnamon', 'blueberry pie filling']
# ********************
# 202. blueberry pizza
# ['all-purpose flour', 'granulated sugar', 'baking powder', 'lemon zest', 'salt', 'ricotta cheese', 'unsalted butter', 'egg yolk', 'water', 'pure vanilla extract', 'blueberries']
# ********************
# 203. bobby flay s chicago deep dish pizza dough  throwdown recipe
# ['dry yeast', 'warm water', 'vegetable oil', 'olive oil', 'yellow cornmeal', 'all-purpose flour', 'kosher salt', 'unsalted butter']
# ********************
# 204. boboli pizza
# ['boboli pizza crust', 'oil', 'pepper', 'garlic clove', 'tomatoes', 'blue cheese', 'dried oregano']
# ********************
# 205. boboli pizza crust
# ['dry yeast', 'sugar', 'warm water', 'water', 'olive oil', 'flour', 'salt', 'kosher salt', 'black pepper', 'thyme']
# ********************
# 206. boboli pizza crust clone
# ['water', 'olive oil', 'garlic', 'salt', 'sugar', 'all-purpose flour', 'italian seasoning', 'parmesan cheese', 'active dry yeast']
# ********************
# 207. bolognese pizza pie
# ['bolognese sauce', 'prepared pizza crust', 'red capsicum', 'mushrooms', 'mozzarella cheese']
# ********************
# 208. bolognese style pan pizza
# ['italian sausage', 'lean ground beef', 'italian-style tomato sauce', 'olive oil', 'prepared pizza crust', 'ricotta cheese', 'egg', 'italian cheese blend']
# ********************
# 209. bountiful brunch pizza
# ['hash browns', 'egg', 'salt and pepper', 'eggs', 'milk', 'ham', 'green bell pepper', 'fresh mushrooms', 'green onion', 'cheddar cheese']
# ********************
# 210. boursin cheese and sun dried tomato pizza
# ['pizza crust', 'pesto sauce', 'boursin cheese', 'sun-dried tomatoes', 'roasted red peppers', 'salami', 'mozzarella cheese']
# ********************
# 211. braided stuffed pizza bread
# ['pizza dough', 'spreadable cheese with garlic and herbs', 'canadian bacon', 'pepperoni', 'mozzarella cheese', 'parmesan cheese', 'egg yolk', 'water', 'poppy seed', 'pizza sauce']
# ********************
# 212. bread machine basic pizza dough
# ['warm water', 'vegetable oil', 'salt', 'bread flour', 'bread machine yeast', 'cornmeal']
# ********************
# 213. bread machine pizza crust
# ['sugar', 'salt', 'cornmeal', 'whole wheat flour', 'unbleached white flour', 'water', 'olive oil', 'yeast']
# ********************
# 214. bread machine pizza crust and dairy free toppings
# ['warm water', 'honey', 'olive oil', 'flour', 'salt', 'yeast', 'cornmeal', 'pizza sauce', 'cheese']
# ********************
# 215. bread machine pizza dough
# ['warm water', 'salt', 'olive oil', 'all-purpose flour', 'sugar', 'bread machine yeast']
# ********************
# 216. bread machine pizza dough with whole wheat flour
# ['water', 'olive oil', 'salt', 'all-purpose flour', 'whole wheat flour', 'yeast']
# ********************
# 217. bread machine whole wheat pizza crust
# ['warm water', 'olive oil', 'honey', 'whole wheat flour', 'parmesan cheese', 'salt', 'active dry yeast']
# ********************
# 218. breadless portabella mushroom pizzas   stove top
# ['portabella mushrooms', 'mozzarella cheese', 'marinara sauce', 'sunflower oil', 'fresh spinach', 'onion', 'soy pepperoni']
# ********************
# 219. breadmaker pizza base  yummiest ever found
# ['warm water', 'sugar', 'salt', 'olive oil', 'cornmeal', 'plain flour', 'baking powder', 'garlic powder', 'onion powder', 'granulated yeast']
# ********************
# 220. breadsticks   pizza hut style
# ['warm water', 'olive oil', 'flour', 'salt', 'oregano', 'powdered milk', 'yeast', 'dry parmesan cheese', 'garlic powder', 'garlic salt', 'onion powder']
# ********************
# 221. breakfast  pizza   somersize
# ['bulk sausage', 'cheddar cheese', 'eggs', 'diced tomato', 'fresh mushrooms']
# ********************
# 222. breakfast crescent pizza
# ['crescent rolls', 'sausage', 'bacon', 'hash brown', 'cheddar cheese', 'eggs', 'milk', 'salt and pepper']
# ********************
# 223. breakfast pita pizza
# ['olive oil', 'red onion', 'red bell pepper', 'eggs', 'salt', 'ground black pepper', 'whole wheat pita bread', 'low-fat cheddar cheese', 'pancetta']
# ********************
# 224. breakfast pizza
# ['refrigerated crescent dinner rolls', 'bacon', 'butter', 'all-purpose flour', 'salt', 'black pepper', 'milk', 'sharp cheddar cheese', 'green onion', 'red bell pepper']
# ********************
# 225. breakfast pizza  rsc
# ['active dry yeast', 'honey', 'warm water', 'flour', 'extra virgin olive oil', 'salt', 'pork sausage', 'eggs', 'half-and-half cream', 'hidden valley original ranch seasoning mix', 'dried chives', 'butter', 'red potatoes', 'vegetable oil', 'hidden valley original ranch dressing', 'seasoning salt', 'pizza cheese']
# ********************
# 226. breakfast pizza   delicious
# ['milk', 'flour', 'butter', 'cream cheese', 'bacon', 'turkey sausage', 'eggs', 'garlic powder', 'onion powder', 'cayenne pepper', 'black pepper', 'olive oil', 'pizza dough', 'monterey jack pepper cheese', 'monterey jack cheese']
# ********************
# 227. breakfast pizza from smitten kitchen
# ['prepared pizza crust', 'kosher salt', 'bacon', 'parmesan cheese', 'mozzarella cheese', 'eggs', 'fresh ground black pepper', 'flat leaf parsley', 'chives', 'scallion', 'shallot']
# ********************
# 228. breakfast pizza ii
# ['refrigerated crescent dinner rolls', 'eggs', 'bacon', 'cheddar cheese']
# ********************
# 229. breakfast pizza skillet
# ['bulk italian sausage', 'frozen hash brown potatoes', 'onion', 'green pepper', 'salt', 'pepper', 'sliced mushrooms', 'eggs', 'tomatoes', 'cheddar cheese', 'sour cream', 'salsa']
# ********************
# 230. breakfast pizza squares
# ['breakfast sausage', 'refrigerated crescent dinner rolls', 'eggs', 'milk', 'pepper', 'cheddar cheese']
# ********************
# 231. breakfast pizzas
# ['bacon', 'sliced mushrooms', 'eggs', 'refrigerated crescent dinner rolls', 'cream cheese', 'basil pesto', 'mozzarella cheese', 'italian plum tomatoes', 'green onions', 'cooking spray']
# ********************
# 232. breakfast sausage pizza
# ['sausage', 'cheddar cheese', 'hash brown potatoes', 'pizza crust', 'parmesan cheese', 'eggs', 'milk', 'salt', 'pepper']
# ********************
# 233. bree s vegetarian pizza
# ['boboli pizza crust', 'onion', 'bell pepper', 'shiitake mushroom', 'black olives', 'cheese', 'tomato sauce']
# ********************
# 234. brie and cranberry pizza
# ['refrigerated crescent dinner rolls', 'brie cheese', 'whole berry cranberry sauce', 'pecans']
# ********************
# 235. brie and pear pizza
# ['unsalted butter', 'extra virgin olive oil', 'onions', 'kosher salt', 'fresh ground black pepper', 'balsamic vinegar', 'curry powder', 'pizza dough', 'brie cheese', 'bosc pears', 'chives']
# ********************
# 236. bring on the breakfast pizza  hungry girl  2 ww points
# ['fat free egg substitute', 'fat free mozzarella cheese', 'canned tomato sauce', 'green bell peppers', 'mushrooms', 'salt']
# ********************
# 237. broccoli chicken pizza
# ['pizza crust', 'broccoli', 'boneless chicken breast', 'olive oil', 'oregano', 'basil', 'part-skim ricotta cheese', 'mozzarella cheese', 'cheddar cheese', 'dry mustard', 'crushed red pepper flakes']
# ********************
# 238. broccoli pizza crust
# ['cooked broccoli', 'eggs', 'mozzarella cheese', 'cheddar cheese', 'garlic powder']
# ********************
# 239. broccoli rabe pizza
# ['broccoli rabe', 'italian sausage', 'sun-dried tomato', 'garlic', 'mozzarella cheese', 'fresh basil', 'crushed red pepper flakes', 'pizza dough', 'olive oil']
# ********************
# 240. broccoli chicken white pizza
# ['pizza dough', 'ground chicken', 'broccoli florets', 'goat cheese', 'mozzarella cheese', 'garlic', 'salt', 'pepper', 'dried thyme', 'olive oil']
# ********************
# 241. brown rice pizza wheat free recipe
# ['cooked brown rice', 'egg whites', 'mozzarella cheese', 'vegetable oil cooking spray', 'pizza sauce', 'garlic powder', 'black pepper', 'parmesan cheese', 'sliced mushrooms', 'ripe olives', 'red pepper']
# ********************
# 242. brownie fruit pizza
# ['refrigerated brownie bar dough', 'cream cheese', 'sugar', 'vanilla', 'fresh strawberries', 'fresh blueberries', 'fresh raspberry', 'apple jelly']
# ...
# ********************
# 2380. white knight pizza
# ['prepared pizza crust', 'basil pesto', 'onion', 'cooked chicken', 'roma tomato', 'mozzarella cheese', 'pine nuts', 'olive oil', 'salt and pepper']
# ********************
# 2381. white pesto pizza
# ['parsley', 'basil', 'garlic cloves', 'olive oil', 'parmesan cheese', 'basic pizza dough', 'ricotta cheese', 'part-skim mozzarella cheese', 'skim milk', 'plum tomatoes', 'beef broth']
# ********************
# 2382. white pizza
# ['frozen dinner rolls', 'butter', 'garlic powder', 'parsley flakes', 'parmesan cheese', 'artichoke hearts', 'mozzarella cheese', 'havarti cheese', 'provolone cheese', 'cracked black pepper']
# ********************
# 2383. white pizza appetizers
# ['hickory smoked bacon', 'italian bread', 'green onion', 'fresh garlic', 'fresh mozzarella cheese']
# ********************
# 2384. white pizza appetizers  puff pastry
# ['puff pastry sheet', 'garlic powder', 'mozzarella cheese', 'pitted ripe olives', 'green peppers', 'dried oregano leaves']
# ********************
# 2385. white pizza dip
# ['herb with garlic soup mix', 'sour cream', 'ricotta cheese', 'mozzarella cheese', 'pepperoni', 'tortilla chips']
# ********************
# 2386. white pizza n e penna  style
# ['bread flour', 'salt', 'sugar', 'dry yeast', 'water', 'oregano', 'american cheese', 'mozzarella cheese', 'muenster cheese', 'rosemary', 'black pepper', 'olive oil']
# ********************
# 2387. white pizza or pizza blanca
# ['onions', 'minced garlic cloves', 'red pepper flakes', 'parmesan cheese', 'mozzarella cheese']
# ********************
# 2388. white pizza pinwheels
# ['refrigerated crescent dinner rolls', 'cream cheese', 'alfredo sauce', 'fresh mushrooms', 'green onion', 'garlic powder', 'mozzarella cheese']
# ********************
# 2389. white pizza sauce
# ['butter', 'flour', 'milk', 'salt', 'pepper', 'garlic clove', 'fresh basil', 'parmigiano-reggiano cheese']
# ********************
# 2390. white pizza with caramelized onion and chicken
# ['butter', 'olive oil', 'red onion', 'brown sugar', 'whole milk', 'cornstarch', 'garlic clove', 'garlic salt', 'onion powder', 'oregano', 'salt', 'pepper', 'nutmeg', 'prepared pizza crust', 'garlic cloves', 'cheese', 'cooked chicken breast', 'cherry tomatoes', 'capers', 'basil', 'pineapple tidbits', 'ricotta cheese']
# ********************
# 2391. white pizza with shellfish
# ['pizza dough', 'olive oil', 'monterey jack cheese', 'garlic', 'scallops', 'shrimp', 'tomatoes', 'green pepper', 'salt & freshly ground black pepper']
# ********************
# 2392. white pizza  chicken and mushroom thin crust
# ['dry active yeast', 'sugar', 'flour', 'warm water', 'salt', 'extra virgin olive oil', 'chicken breasts', 'canola oil', 'butter', 'garlic', 'red pepper flakes', 'dried oregano', 'dried basil', 'garlic powder', 'white mushrooms', 'mozzarella cheese', 'asiago cheese', 'cornmeal']
# ********************
# 2393. white sauce pizza dip
# ['lipton recipe secrets savory herb with garlic soup mix', 'cottage cheese', 'sour cream', 'mozzarella cheese', 'pepperoni slice', 'bread']
# ********************
# 2394. white spinach pizza   oamc
# ['frozen chopped spinach', 'milk', 'flour', 'garlic clove', 'pizza dough', 'dried basil', 'dried oregano', 'feta cheese', 'mozzarella cheese', 'salt and pepper']
# ********************
# 2395. whole grain hawaiian pizza
# ['warm water', 'yeast', 'bread flour', 'wheat bran', 'canola oil', 'salt', 'tomato sauce', 'part-skim mozzarella cheese', 'canadian bacon', 'pineapple tidbits']
# ********************
# 2396. whole grain pizza dough
# ['water', 'fast rising yeast', 'olive oil', 'molasses', 'sea salt', 'whole wheat flour', 'spelt flour']
# ********************
# 2397. whole wheat  yeast free  herbed pizza dough
# ['all-purpose flour', 'whole wheat flour', 'cornmeal', 'granulated sugar', 'dried italian herb seasoning', 'baking powder', 'baking soda', 'plain fat-free yogurt', 'olive oil']
# ********************
# 2398. whole wheat and semolina flour pizza dough
# ['hot water', 'sugar', 'yeast', 'whole wheat flour', 'bread flour', 'semolina flour', 'salt']
# ********************
# 2399. whole wheat beef  n  pepper pizza
# ['whole wheat flour', 'skim milk', 'eggs', 'oregano leaves', 'salt', 'ground beef', 'onion', 'garlic cloves', 'green bell pepper', 'pepper', 'red pepper flakes', 'pizza sauce', 'lowfat mozzarella cheese']
# ********************
# 2400. whole wheat bread machine pizza dough
# ['water', 'olive oil', 'salt', 'flour', 'whole wheat flour', 'yeast']
# ********************
# 2401. whole wheat pizza crust
# ['water', 'honey', 'olive oil', 'salt', 'whole wheat flour', 'vital wheat gluten', 'yeast', 'garlic powder']
# ********************
# 2402. whole wheat pizza crust fleischmann
# ['yeast', 'warm water', 'sugar', 'flour', 'whole wheat flour', 'salt', 'corn oil']
# ********************
# 2403. whole wheat pizza crust for bread machine
# ['water', 'olive oil', 'all-purpose flour', 'whole wheat flour', 'sugar', 'salt', 'yeast']
# ********************
# 2404. whole wheat pizza dough
# ['all-purpose flour', 'whole wheat flour', 'salt', 'active dry yeast', 'olive oil', 'sugar', 'water', 'warm water']
# ********************
# 2405. whole wheat pizza dough   pizza sauce
# ['olive oil', 'dry yeast', 'sugar', 'water', 'oil', 'whole wheat flour', 'unbleached flour', 'salt', 'onion', 'tomato sauce', 'tomato paste', 'oregano', 'garlic salt', 'pepper']
# ********************
# 2406. whole wheat pizza dough  bread machine
# ['water', 'salt', 'extra virgin olive oil', 'bread flour', 'whole wheat flour', 'active dry yeast', 'italian seasoning']
# ********************
# 2407. whole wheat quick pizza dough
# ['yeast', 'water', 'olive oil', 'whole wheat flour', 'all-purpose flour', 'garlic powder']
# ********************
# 2408. whole wheat pizza dough
# ['water', 'active dry yeast', 'sugar', 'salt', 'whole wheat flour', 'all-purpose flour', 'walnut oil']
# ********************
# 2409. wicked chicken  hidden valley ranch pizza  rsc
# ['pizza dough', 'greek yogurt', 'hidden valley original ranch dips mix', 'garlic cloves', 'chicken tenders', 'extra virgin olive oil', 'baby portabella mushrooms', 'baby spinach leaves', 'mozzarella cheese', 'parmesan cheese', 'pepper']
# ********************
# 2410. wicked good pizza muffins for kids
# ['flour', 'sugar', 'baking powder', 'salt', 'dried basil', 'baking soda', 'cheddar cheese', 'sour cream', 'eggs', 'butter', 'green pepper', 'pizza sauce', 'mozzarella cheese']
# ********************
# 2411. wild mushroom pizza
# ['olive oil', 'mushroom', 'salt and black pepper', 'onion', 'garlic cloves', 'fresh parsley', 'thin pizza crust', 'parmesan cheese']
# ********************
# 2412. wild mushroom pizza with caramelized onions  sun dried tomato
# ['fat-free whole wheat pita bread', 'smart balance light butter spread', 'onion', 'wild mushroom', 'garlic cloves', 'shallot', 'dry white wine', 'fresh basil', 'sun-dried tomatoes', 'reduced-fat mozzarella cheese']
# ********************
# 2413. wild mushroom pizza with truffle oil
# ['sugar', 'fast rise yeast', 'warm water', 'all-purpose flour', 'salt', 'cooking spray', 'cornmeal', 'olive oil', 'shiitake mushroom caps', 'cremini mushrooms', 'portabella mushrooms', 'fontina cheese', 'fresh thyme', 'truffle oil', 'fresh parmesan cheese', 'sea salt']
# ********************
# 2414. wild mushroom  red onion and sage pizza
# ['white mushrooms', 'wild mushrooms', 'red onion', 'olive oil', 'salt', 'black pepper', 'pizza crust', 'dried sage', 'mozzarella cheese', 'fresh parsley']
# ********************
# 2415. wildcat hot pizza dip
# ['cream cheese', 'dried oregano', 'dried parsley', 'dried basil', 'mozzarella cheese', 'parmesan cheese', 'pizza sauce', 'green bell peppers', 'pepperoni', 'black olives']
# ********************
# 2416. willa s pizza loaf
# ['italian bread', 'marinara sauce', 'sweet italian sausage links', 'cooked ham', 'mozzarella cheese', 'sharp cheddar cheese', 'black olives', 'button mushroom', 'pineapple chunks', 'crushed red pepper flakes']
# ********************
# 2417. wingless buffalo chicken pizza
# ['boneless skinless chicken breast', 'extra virgin olive oil', 'mccormick grill seasoning', 'pizza dough', 'butter', 'worcestershire sauce', 'hot sauce', 'tomato sauce', 'monterey jack cheese', 'blue cheese', 'scallions']
# ********************
# 2418. wonderful chicken pizza with fresh basil
# ['olive oil', 'garlic', 'tomato paste', 'ground coriander', 'dried oregano', 'ground cumin', 'salt', 'crushed red pepper flakes', 'dry white wine', 'ketchup', 'lemon, juice of', 'fresh basil', 'boneless skinless chicken breast halves', 'salt & freshly ground black pepper', 'dried basil', 'red bell pepper', 'mozzarella cheese', 'parmesan cheese']
# ********************
# 2419. wood fired oven pizza dough
# ['warm water', 'dry yeast', 'salt', 'honey', 'unbleached flour']
# ********************
# 2420. woody s pizza crust
# ['water', 'active dry yeast', 'sugar', 'olive oil', 'salt', 'pizza seasoning', 'all-purpose flour', 'cornmeal']
# ********************
# 2421. world s best pizza crust
# ['yeast', 'sugar', 'warm water', 'flour', 'salt', 'oil']
# ********************
# 2422. ww 3 points   onion and olive pizza squares
# ['olive oil', 'red onions', 'sugar', 'salt', 'oil-cured black olives', 'fresh oregano', 'pizza dough', 'goat cheese', 'basil']
# ********************
# 2423. ww 4 points   easy mexican pizzas
# ['olive oil', 'ground turkey breast', 'onion', 'taco seasoning mix', 'stewed tomatoes', 'water', 'corn tortillas', 'reduced-fat cheddar cheese', 'olives', 'pickled jalapeno pepper']
# ********************
# 2424. ww 4 points   grilled mushroom sausage pizza
# ['prepared pizza crust', 'yellow tomatoes', 'wild mushrooms', 'red onion', 'chicken sausage', 'mozzarella cheese', 'fresh basil leaf']
# ********************
# 2425. ww 5 point pizza
# ['whole wheat english muffin', 'pizza sauce', 'part-skim mozzarella cheese', 'butter-flavored cooking spray', 'garlic salt']
# ********************
# 2426. ww 6 points   grilled chicken pizza
# ['cooked chicken breasts', 'fresh basil', 'extra virgin olive oil', 'garlic cloves', 'salt', 'fresh ground pepper', 'whole wheat french bread', 'smoked mozzarella cheese']
# ********************
# 2427. ww chicken   pumpkin pizza 7 5pts australian ww
# ['lebanese bread', 'tomato paste', 'pumpkin', 'lean chicken', 'tasty cheese', 'black olives']
# ********************
# 2428. ww core   bubbling pizza casserole
# ['96% lean ground beef', 'onion', 'tomato sauce', 'dried basil', 'garlic cloves', 'italian seasoning', 'sliced mushrooms', 'bell pepper', 'diced tomato', 'refrigerated biscuits', 'fat free mozzarella cheese']
# ********************
# 2429. ww core polenta crust pizza
# ['water', 'yellow cornmeal', 'salt', 'fresh ground black pepper', 'basil', 'oregano', 'extra virgin olive oil', 'tomato paste', 'red pepper', 'green pepper', 'red onion', 'mushroom', 'vegan sausage links', 'black olives', 'garlic cloves']
# ********************
# 2430. ww core zucchini crust cheese pizza
# ['zucchini', 'eggs', 'cornmeal', 'mozzarella cheese', 'fat free parmesan', 'dried basil', 'tomato sauce', 'mushroom', 'tomatoes', 'onion', 'garlic cloves', 'salt', 'pepper']
# ********************
# 2431. ww gourmet pizza
# ['vidalia onions', 'pizza crusts', 'sun-dried tomatoes', 'hard cheese', 'spinach', 'black pepper']
# ********************
# 2432. ww pizza pasta
# ['ground round', 'pizza sauce', 'salt', 'pepper', 'cooked elbow macaroni', 'reduced-fat sharp cheddar cheese']
# ********************
# 2433. yeast free pizza crust  gluten free
# ['cornstarch', 'rice flour', '2% low-fat milk', 'eggs', 'salt', 'italian spices', 'garlic powder']
# ********************
# 2434. yeast free pizza with fresh basil and tomatoes
# ['all-purpose flour', 'baking powder', 'salt', 'milk', 'extra virgin olive oil', 'garlic cloves', 'part-skim mozzarella cheese', 'roma tomato', 'parmesan cheese', 'fresh basil leaves', 'part-skim ricotta cheese']
# ********************
# 2435. yum italian pizza base
# ['plain flour', 'bread flour', 'dried yeast', 'sea salt', 'sugar', 'extra virgin olive oil', 'warm water']
# ********************
# 2436. yummy fruit pizza
# ['margarine', 'egg', 'brown sugar', 'flour', 'baking powder', 'baking soda', 'rolled oats', 'coconut', 'cream cheese', 'icing sugar', 'sugar', 'pineapple juice', 'water', 'cornstarch']
# ********************
# 2437. yummy pepperoni pizza breadsticks
# ['active dry yeast', 'warm water', 'olive oil', 'salt', 'dill', 'rosemary', 'italian seasoning', 'garlic powder', 'sourdough starter', 'all-purpose flour', 'pepperoni', 'parmesan cheese', 'mozzarella cheese', 'green onion', 'marinara sauce']
# ********************
# 2438. yummy  good for you pizza   also my family s favorite
# ['active dry yeast', 'warm water', 'honey', 'olive oil', 'whole wheat flour', 'cornmeal', 'sea salt', 'all-purpose flour', 'spinach leaves', 'fresh basil leaf', 'garlic cloves', 'parmesan cheese', 'lemon juice', 'turkey pepperoni', 'plum tomato', 'reduced-fat mozzarella cheese']
# ********************
# 2439. zero carb pizza
# ['mozzarella cheese', 'eggs', 'oregano', 'basil']
# ********************
# 2440. zesty chicken and garlic white pizza
# ['boneless skinless chicken breast', 'butter', 'garlic cloves', 'green onions', 'fresh basil', 'pizza dough', 'roma tomatoes', 'fresh cilantro', 'ricotta cheese', 'parmesan cheese']
# ********************
# 2441. zesty pizza casserole
# ['ground beef', 'onion', 'green bell pepper', 'pizza sauce', 'sliced mushrooms', 'pepperoni', 'salt', 'dried oregano', 'garlic powder', 'dried basil', 'elbow macaroni', 'mozzarella cheese']
# ********************
# 2442. zippy chicken salsa pizza
# ['bread pizza crust', 'cheddar cheese', 'salsa', 'cooked chicken']
# ********************
# 2443. zoe s favorite english muffin pizza
# ['english muffin', 'pizza sauce', 'mozzarella cheese', 'vegetables']
# ********************
# 2444. zucchini and fresh tomato pizza with fontina
# ['onions', 'garlic', 'salt', 'olive oil', 'ground fennel', 'zucchini', 'fresh tomatoes', 'fresh basil', 'pizza dough', 'fontina cheese']
# ********************
# 2445. zucchini crust pizza
# ['zucchini', 'egg substitute', 'all-purpose flour', 'salt', 'part-skim mozzarella cheese', 'tomatoes', 'onion', 'green pepper', 'sweet red pepper', 'dried oregano', 'dried basil', 'parmesan cheese']
# ********************
# 2446. zucchini crusted pizza
# ['zucchini', 'eggs', 'flour', 'mozzarella cheese', 'parmesan cheese', 'basil leaves', 'pizza sauce', 'mushroom', 'italian sausage', 'provolone cheese']
# ********************
# 2447. zucchini crusted pizza base
# ['zucchini', 'eggs', 'flour', 'mozzarella cheese', 'parmesan cheese', 'basil', 'olive oil']
# ********************
# 2448. zucchini pizza
# ['fresh zucchini', 'olive oil', 'flour', 'eggs', 'mozzarella cheese', 'parmesan cheese', 'basil', 'rosemary', 'tomatoes', 'garlic clove', 'sliced mushrooms', 'green bell pepper', 'black olives']
# ********************
# 2449. zucchini pizza boats
# ['zucchini', 'tomato sauce', 'black olives', 'breadcrumbs', 'parmesan cheese', 'italian seasoning', 'mozzarella cheese']
# ********************
# 2450. zucchini pizza casserole
# ['zucchini', 'salt', 'eggs', 'parmesan cheese', 'part-skim mozzarella cheese', 'shredded cheddar cheese', 'ground beef', 'onion', 'tomato sauce', 'green pepper']
# ********************
# 2451. zucchini pizza crust
# ['zucchini', 'salt', 'eggs', 'reduced-fat mozzarella cheese', 'garlic cloves', 'fresh ground black pepper', 'tomatoes', 'green onion', 'goat cheese', 'fresh basil']
# ********************
# 2452. zucchini pizza dough
# ['zucchini', 'bread flour', 'egg whites', 'parmesan cheese', 'fresh basil', 'cremini mushroom', 'salt and pepper']
# ********************
# 2453. zucchini roni pizza
# ['red peppers', 'lowfat mozzarella cheese', 'zucchini', 'garlic cloves', 'crushed red pepper flakes', 'dried italian seasoning', 'olive oil', 'pizza crust']
# ********************
#
#         ******************************
#         *        Welcome        *
#         * Search by materials........1 *
#         * Random Suggestion............2 *
#         * Search by TAG............3 *
#         * Search by the food name......4 *
#         * Exit....................q *
#         ***********************
#
# Bon Appetit!
# Have a nice day!
