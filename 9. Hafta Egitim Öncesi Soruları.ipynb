# %% [markdown]
# # Problem 1
# Vehicle sınıfından miras alan bir Bus sınıfı oluşturun. Bus.seating_capacity()'nin kapasite bağımsız değişkenine varsayılan olarak 50 değerini verin.
#
# ```
# Output:
# > The seating capacity of a bus is 50 passengers
# ```

# %%
class Vehicle:
    def __init__(self, kapasite):
        self.kapasite = kapasite

class Bus(Vehicle):
    def __init__(self, kapasite):
        self.capacity = kapasite
    
    def seating_capacity(self, kapasite=50):
        return f"This bus has a seating capacity of {kapasite} passengers."
otobus = Bus(30)
print(otobus.seating_capacity())
# Out:
# This bus has a seating capacity of 50 passengers.

# %% [markdown]
# # Problem 2
#
#
# School_bus'ın aynı zamanda Vehicle sınıfının bir örneği olup olmadığını belirleyiniz.

# %%
class Vehicle:
    def __init__(self, kapasite):
        self.kapasite = kapasite

class Bus(Vehicle):
    def __init__(self, kapasite):
        self.capacity = kapasite
    
    def seating_capacity(self, kapasite=50):
        return f"This bus has a seating capacity of {kapasite} passengers."
otobus = Bus(30)
print(otobus.seating_capacity())
print(isinstance(otobus, Vehicle))
# Out:
# This bus has a seating capacity of 50 passengers.
# True
